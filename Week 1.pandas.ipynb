# %%
print ("Hello World!!")
# Out:
# Hello World!!

# %%
pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 270.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/168.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/168.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/168.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/168.5 kB 217.9 kB/s eta 0:00:01
#      --------- ---------------------------- 41.0/168.5 kB 78.8 kB/s eta 0:00:02
#      --------- ---------------------------- 41.0/168.5 kB 78.8 kB/s eta 0:00:02
#      --------- ---------------------------- 41.0/168.5 kB 78.8 kB/s eta 0:00:02
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
name = ['Messi', 'Ronaldo','Neymar','Hazard','De Bruyne']
kit_number = [10, 7, 10, 7, 17] 
rating = [93, 93, 91, 91, 91]

# %%
df = pd.DataFrame({
    'Name': name,
    'Kit_number': kit_number,
    'Rating': rating
})
df
# Out:
#         Name  Kit_number  Rating
# 0      Messi          10      93
# 1    Ronaldo           7      93
# 2     Neymar          10      91
# 3     Hazard           7      91
# 4  De Bruyne          17      91
